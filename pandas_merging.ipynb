# %% [markdown]
# <a href="https://colab.research.google.com/github/rabiyulfahimhasim786/pandas/blob/main/pandas_merging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data1 = pd.read_csv("text.csv", encoding= 'unicode_escape', header=0, dtype=str)
data1.head()
# Out:
#   Unnamed: 0  PageNo                                               Text
# 0          0  page_1  ['Notice', 'CP140', 'Department of the Treasur...

# %%
data1.shape
# Out:
# (1, 3)

# %%
data2 = pd.read_csv("key_value.csv", encoding= 'unicode_escape', header=0, dtype=str)
data2.head()
# Out:
#   Unnamed: 0                Keys             Values
# 0          0            Tax form                941
# 1          1              Notice              CP140
# 2          2         Notice date  November 21, 2022
# 3          3  Employer ID number         XX-XXX8584
# 4          4          Tax period      June 30, 2020

# %%
data2.shape
# Out:
# (10, 3)

# %%
data3 = pd.read_csv("datas.csv", encoding= 'unicode_escape', header=0, dtype=str)
data3.head()
# Out:
#      0         1       2      3
# 0  NaN  22 - PET  494016  $2.99
# 1    1  22 - PET  501290  $2.99
# 2    2  22 - PET  452039  $6.99

# %%
data3.shape
# Out:
# (3, 4)

# %%
concate_data = pd.concat([data1,data2,data3], ignore_index=True)
concate_data.head()
# Out:
#   Unnamed: 0  PageNo                                               Text  \
# 0          0  page_1  ['Notice', 'CP140', 'Department of the Treasur...
# 1          0     NaN                                                NaN
# 2          1     NaN                                                NaN
# 3          2     NaN                                                NaN
# 4          3     NaN                                                NaN
#
#                  Keys             Values    0    1    2    3
# 0                 NaN                NaN  NaN  NaN  NaN  NaN
# 1            Tax form                941  NaN  NaN  NaN  NaN
# 2              Notice              CP140  NaN  NaN  NaN  NaN
# 3         Notice date  November 21, 2022  NaN  NaN  NaN  NaN
# 4  Employer ID number         XX-XXX8584  NaN  NaN  NaN  NaN

# %%
concate_data.to_csv('data.csv', index=False)
# c = concate_data.dropna
# c
concate_data
# Out:
#    Unnamed: 0  PageNo                                               Text  \
# 0           0  page_1  ['Notice', 'CP140', 'Department of the Treasur...
# 1           0     NaN                                                NaN
# 2           1     NaN                                                NaN
# 3           2     NaN                                                NaN
# 4           3     NaN                                                NaN
# 5           4     NaN                                                NaN
# 6           5     NaN                                                NaN
# 7           6     NaN                                                NaN
# 8           7     NaN                                                NaN
# 9           8     NaN                                                NaN
# 10          9     NaN                                                NaN
# 11        NaN     NaN                                                NaN
# 12        NaN     NaN                                                NaN
# 13        NaN     NaN                                                NaN
#
#                                                  Keys  \
# 0                                                 NaN
# 1                                            Tax form
# 2                                              Notice
# 3                                         Notice date
# 4                                  Employer ID number
# 5                                          Tax period
# 6                                       To contact us
# 7                                     Taxpayer number
# 8   Current law requires us to contract with quali...
# 9                              Additional information
# 10            You can also find the following online:
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
#
#                                                Values    0         1       2  \
# 0                                                 NaN  NaN       NaN     NaN
# 1                                                 941  NaN       NaN     NaN
# 2                                               CP140  NaN       NaN     NaN
# 3                                   November 21, 2022  NaN       NaN     NaN
# 4                                          XX-XXX8584  NaN       NaN     NaN
# 5                                       June 30, 2020  NaN       NaN     NaN
# 6                                  Phone 844-875-3420  NaN       NaN     NaN
# 7                                          6399084080  NaN       NaN     NaN
# 8   COAST PROFESSIONAL, INC. PO BOX 425 GENESEO, N...  NaN       NaN     NaN
# 9                                     VALUE_NOT_FOUND  NaN       NaN     NaN
# 10  Publication 1, Your Rights as a Taxpayer For t...  NaN       NaN     NaN
# 11                                                NaN  NaN  22 - PET  494016
# 12                                                NaN    1  22 - PET  501290
# 13                                                NaN    2  22 - PET  452039
#
#         3
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11  $2.99
# 12  $2.99
# 13  $6.99

# %%
import pandas as pd

a = pd.read_csv("text.csv")
b = pd.read_csv("key_value.csv")
frames=[a,b]
mergedFrames=pd.DataFrame()
mergedFrames=pd.concat(frames, ignore_index=True)
mergedFrames.to_csv('test.csv')
mergedFrames
# Out:
#     Unnamed: 0  PageNo                                               Text  \
# 0            0  page_1  ['Notice', 'CP140', 'Department of the Treasur...
# 1            0     NaN                                                NaN
# 2            1     NaN                                                NaN
# 3            2     NaN                                                NaN
# 4            3     NaN                                                NaN
# 5            4     NaN                                                NaN
# 6            5     NaN                                                NaN
# 7            6     NaN                                                NaN
# 8            7     NaN                                                NaN
# 9            8     NaN                                                NaN
# 10           9     NaN                                                NaN
#
#                                                  Keys  \
# 0                                                 NaN
# 1                                            Tax form
# 2                                              Notice
# 3                                         Notice date
# 4                                  Employer ID number
# 5                                          Tax period
# 6                                       To contact us
# 7                                     Taxpayer number
# 8   Current law requires us to contract with quali...
# 9                              Additional information
# 10            You can also find the following online:
#
#                                                Values
# 0                                                 NaN
# 1                                                 941
# 2                                               CP140
# 3                                   November 21, 2022
# 4                                          XX-XXX8584
# 5                                       June 30, 2020
# 6                                  Phone 844-875-3420
# 7                                          6399084080
# 8   COAST PROFESSIONAL, INC. PO BOX 425 GENESEO, N...
# 9                                     VALUE_NOT_FOUND
# 10  Publication 1, Your Rights as a Taxpayer For t...

# %% [markdown]
# **merging succeesful method**

# %%
import pandas as pd
import io

csv_list = ('text.csv', 'key_value.csv', 'datas.csv')

#df_master = pd.read_csv('filepaths.csv')
prefix_df = []
for csv_file in csv_list:
    df = pd.read_csv(csv_file, encoding='utf8',  header=None,  dtype=str)
    #df.to_csv('filepaths.csv', mode='a', header=False, index=False)
    #test = pd.concat(df, ignore_index=True)
    prefix_df.append(df)
    data = pd.concat(prefix_df, ignore_index=True)
data
# Out:
#       0                                                  1  \
# 0   NaN                                             PageNo
# 1     0                                             page_1
# 2   NaN                                               Keys
# 3     0                                           Tax form
# 4     1                                             Notice
# 5     2                                        Notice date
# 6     3                                 Employer ID number
# 7     4                                         Tax period
# 8     5                                      To contact us
# 9     6                                    Taxpayer number
# 10    7  Current law requires us to contract with quali...
# 11    8                             Additional information
# 12    9            You can also find the following online:
# 13    0                                                  1
# 14  NaN                                           22 - PET
# 15    1                                           22 - PET
# 16    2                                           22 - PET
#
#                                                     2      3
# 0                                                Text    NaN
# 1   ['Notice', 'CP140', 'Department of the Treasur...    NaN
# 2                                              Values    NaN
# 3                                                 941    NaN
# 4                                               CP140    NaN
# 5                                   November 21, 2022    NaN
# 6                                          XX-XXX8584    NaN
# 7                                       June 30, 2020    NaN
# 8                                  Phone 844-875-3420    NaN
# 9                                          6399084080    NaN
# 10  COAST PROFESSIONAL, INC. PO BOX 425 GENESEO, N...    NaN
# 11                                    VALUE_NOT_FOUND    NaN
# 12  Publication 1, Your Rights as a Taxpayer For t...    NaN
# 13                                                  2      3
# 14                                             494016  $2.99
# 15                                             501290  $2.99
# 16                                             452039  $6.99

# %%
data.to_csv('sampledatas2.csv', index=False)

# %%
# Using data library
import dask.dataframe as dd
df = dd.read_csv("*.csv")
df
# Out:
# Dask DataFrame Structure:
#               Unnamed: 0  PageNo    Text    Keys  Values        0        1        2        3
# npartitions=6
#                    int64  object  object  object  object  float64  float64  float64  float64
#                      ...     ...     ...     ...     ...      ...      ...      ...      ...
# ...                  ...     ...     ...     ...     ...      ...      ...      ...      ...
#                      ...     ...     ...     ...     ...      ...      ...      ...      ...
#                      ...     ...     ...     ...     ...      ...      ...      ...      ...
# Dask Name: read-csv, 6 tasks

# %%
import pandas as pd
filenames = ['table.csv', 'key_value.csv']
combined_csv = pd.concat( [ pd.read_csv(f) for f in filenames ] )
combined_csv
# Out:
#    Unnamed: 0  22 - PET    494016  $2.99  \
# 0           1  22 - PET  501290.0  $2.99
# 1           2  22 - PET  452039.0  $6.99
# 0           0       NaN       NaN    NaN
# 1           1       NaN       NaN    NaN
# 2           2       NaN       NaN    NaN
# 3           3       NaN       NaN    NaN
# 4           4       NaN       NaN    NaN
# 5           5       NaN       NaN    NaN
# 6           6       NaN       NaN    NaN
# 7           7       NaN       NaN    NaN
# 8           8       NaN       NaN    NaN
# 9           9       NaN       NaN    NaN
#
#                                                 Keys  \
# 0                                                NaN
# 1                                                NaN
# 0                                           Tax form
# 1                                             Notice
# 2                                        Notice date
# 3                                 Employer ID number
# 4                                         Tax period
# 5                                      To contact us
# 6                                    Taxpayer number
# 7  Current law requires us to contract with quali...
# 8                             Additional information
# 9            You can also find the following online:
#
#                                               Values
# 0                                                NaN
# 1                                                NaN
# 0                                                941
# 1                                              CP140
# 2                                  November 21, 2022
# 3                                         XX-XXX8584
# 4                                      June 30, 2020
# 5                                 Phone 844-875-3420
# 6                                         6399084080
# 7  COAST PROFESSIONAL, INC. PO BOX 425 GENESEO, N...
# 8                                    VALUE_NOT_FOUND
# 9  Publication 1, Your Rights as a Taxpayer For t...
